# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('adult.csv')

# %% [markdown]
# ##### Q1. Use head(2), head(10), tail(2). Explain your observations, in no more than 2 to 3 lines.
#
# ANSWER

# %%
data.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country class-label
# 0          2174             0              40   United-States       <=50K
# 1             0             0              13   United-States       <=50K

# %%
data.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0     Male          2174             0              40   United-States
# 1     Male             0             0              13   United-States
# 2     Male             0             0              40   United-States
# 3     Male             0             0              40   United-States
# 4   Female             0             0              40            Cuba
# 5   Female             0             0              40   United-States
# 6   Female             0             0              16         Jamaica
# 7     Male             0             0              45   United-States
# 8   Female         14084             0              50   United-States
# 9     Male          5178             0              40   United-States
#
#   class-label
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# 5       <=50K
# 6       <=50K
# 7        >50K
# 8        >50K
# 9        >50K

# %%
data.tail(2)
# Out:
#        age      workclass  fnlwgt education  education-num  \
# 32559   22        Private  201490   HS-grad              9
# 32560   52   Self-emp-inc  287927   HS-grad              9
#
#             marital-status        occupation relationship    race      sex  \
# 32559        Never-married      Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse   Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country class-label
# 32559             0             0              20   United-States       <=50K
# 32560         15024             0              40   United-States        >50K

# %% [markdown]
# EXPLANATION;
# I observed that most of the adult in  this dat from the selected view are all native of America
# 90 percent is a native of United state of American while other are from Cuba and Jamaica

# %% [markdown]
# Generating my Unique datasets

# %%
data = data.sample(n=30000, random_state = 94)

# %%
data.to_csv('samuelosaghae_2120094_ WEEK1.csv')

# %%
data.shape
# Out:
# (30000, 15)

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  30000.000000  3.000000e+04   30000.000000  30000.000000  30000.000000
# mean      38.588733  1.898409e+05      10.077967   1074.551000     87.514767
# std       13.619539  1.051800e+05       2.579698   7394.107726    403.735249
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.179040e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783765e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.377148e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    30000.000000
# mean        40.433033
# std         12.315220
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# from the above the oldest adult is 90years while the youngst is 17years

# %%
data['education-num'].value_counts()
# Out:
# 9     9667
# 10    6714
# 13    4920
# 14    1595
# 11    1268
# 7     1091
# 12     980
# 6      842
# 4      598
# 15     531
# 5      481
# 8      404
# 16     388
# 3      312
# 2      162
# 1       47
# Name: education-num, dtype: int64

# %%
data['education'].value_counts()
# Out:
#  HS-grad         9667
#  Some-college    6714
#  Bachelors       4920
#  Masters         1595
#  Assoc-voc       1268
#  11th            1091
#  Assoc-acdm       980
#  10th             842
#  7th-8th          598
#  Prof-school      531
#  9th              481
#  12th             404
#  Doctorate        388
#  5th-6th          312
#  1st-4th          162
#  Preschool         47
# Name: education, dtype: int64

# %%
data = data.drop(['fnlwgt'], axis=1)

# %% [markdown]
# ###### The above cell will drop/remove 'fnlwgt' from data.
# drop(): To drop a column from the dataframe, pass agruments -
# column name to be dropped and axis = 1. axis = 0 is to dropping row.

# %%
data.shape
# Out:
# (30000, 14)

# %% [markdown]
# After removing the  'fnlwgt' column it is ovbserve  that there are now 14 columns instead of 15.

# %%
data.describe(include='all')
# Out:
#                  age workclass education  education-num       marital-status  \
# count   30000.000000     30000     30000   30000.000000                30000
# unique           NaN         9        16            NaN                    7
# top              NaN   Private   HS-grad            NaN   Married-civ-spouse
# freq             NaN     20935      9667            NaN                13802
# mean       38.588733       NaN       NaN      10.077967                  NaN
# std        13.619539       NaN       NaN       2.579698                  NaN
# min        17.000000       NaN       NaN       1.000000                  NaN
# 25%        28.000000       NaN       NaN       9.000000                  NaN
# 50%        37.000000       NaN       NaN      10.000000                  NaN
# 75%        48.000000       NaN       NaN      12.000000                  NaN
# max        90.000000       NaN       NaN      16.000000                  NaN
#
#              occupation relationship    race    sex  capital-gain  \
# count             30000        30000   30000  30000  30000.000000
# unique               15            6       5      2           NaN
# top      Prof-specialty      Husband   White   Male           NaN
# freq               3815        12174   25608  20097           NaN
# mean                NaN          NaN     NaN    NaN   1074.551000
# std                 NaN          NaN     NaN    NaN   7394.107726
# min                 NaN          NaN     NaN    NaN      0.000000
# 25%                 NaN          NaN     NaN    NaN      0.000000
# 50%                 NaN          NaN     NaN    NaN      0.000000
# 75%                 NaN          NaN     NaN    NaN      0.000000
# max                 NaN          NaN     NaN    NaN  99999.000000
#
#         capital-loss  hours-per-week  native-country class-label
# count   30000.000000    30000.000000           30000       30000
# unique           NaN             NaN              42           2
# top              NaN             NaN   United-States       <=50K
# freq             NaN             NaN           26857       22763
# mean       87.514767       40.433033             NaN         NaN
# std       403.735249       12.315220             NaN         NaN
# min         0.000000        1.000000             NaN         NaN
# 25%         0.000000       40.000000             NaN         NaN
# 50%         0.000000       40.000000             NaN         NaN
# 75%         0.000000       45.000000             NaN         NaN
# max      4356.000000       99.000000             NaN         NaN

# %%
data['education'].value_counts()
# Out:
#  HS-grad         9667
#  Some-college    6714
#  Bachelors       4920
#  Masters         1595
#  Assoc-voc       1268
#  11th            1091
#  Assoc-acdm       980
#  10th             842
#  7th-8th          598
#  Prof-school      531
#  9th              481
#  12th             404
#  Doctorate        388
#  5th-6th          312
#  1st-4th          162
#  Preschool         47
# Name: education, dtype: int64

# %% [markdown]
# value_counts() produces a frequency table, which shows occurance of each feature or attribute in a dataset.

# %%
data['education'].nunique()
# Out:
# 16

# %%
data['age'].value_counts()
# Out:
# 31    827
# 36    825
# 23    814
# 34    811
# 28    796
#      ...
# 83      5
# 88      2
# 85      2
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64

# %% [markdown]
# Age frequency table is too lengthy to be analysed. This is due to 'age' being continuous value
# and frequency of each value is displayed. Let's visualise 'age' through graphs instead to make observations.

# %%
data.boxplot(column='age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# from the above Boxplot, it is seen that the plot gave us the maximun age value as about 79 while the minimum age value as  lower than 20 and then shows that ages of adult above 80 as outliers which is quite different from the data described above

# %%
data['age'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['age'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['sex'].value_counts()
# Out:
#  Male      20097
#  Female     9903
# Name: sex, dtype: int64

# %%
data['native-country'].value_counts()
# Out:
#  United-States                 26857
#  Mexico                          598
#  ?                               541
#  Philippines                     181
#  Germany                         123
#  Canada                          109
#  Puerto-Rico                     104
#  El-Salvador                      99
#  India                            94
#  Cuba                             90
#  England                          81
#  Jamaica                          76
#  South                            74
#  China                            71
#  Italy                            70
#  Vietnam                          65
#  Dominican-Republic               64
#  Guatemala                        61
#  Japan                            57
#  Poland                           51
#  Columbia                         51
#  Taiwan                           47
#  Iran                             42
#  Haiti                            41
#  Portugal                         36
#  Nicaragua                        31
#  Peru                             31
#  France                           27
#  Ecuador                          27
#  Greece                           23
#  Ireland                          20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Hong                             19
#  Laos                             18
#  Thailand                         16
#  Yugoslavia                       15
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Scotland                         12
#  Hungary                          12
#  Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class-label'],
#       dtype='object')

# %%
data['workclass'].value_counts()
# Out:
#  Private             20935
#  Self-emp-not-inc     2331
#  Local-gov            1923
#  ?                    1671
#  State-gov            1198
#  Self-emp-inc         1029
#  Federal-gov           892
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %% [markdown]
# ##### Q2. How many males and females exist in the dataset? In a new cell, use a correct command to answer the question and write your answer.

# %%
data['sex'].value_counts()
# Out:
#  Male      20097
#  Female     9903
# Name: sex, dtype: int64

# %% [markdown]
#    ANSWER:
#                     The number males and females exist in the dataset
#                     Male are 20097 while  Female are  9903

# %% [markdown]
# ##### Question: What is the average age of each gender in the given population?

# %%
data['age'].groupby([data['sex']]).mean()
# Out:
# sex
#  Female    36.819651
#  Male      39.460467
# Name: age, dtype: float64

# %% [markdown]
#    ANSWER:
#             the average of  the male is 39.4604 while the female is 36.819651

# %% [markdown]
# ##### Question. What is the average age of male and female across different educAtion categories?
#
#                 ANSWER

# %%
data['age'].groupby([data['sex'],data['education']]).mean()
# Out:
# sex      education
#  Female   10th            35.296296
#           11th            30.269802
#           12th            29.971014
#           1st-4th         47.800000
#           5th-6th         44.282051
#           7th-8th         49.219178
#           9th             42.180451
#           Assoc-acdm      36.377892
#           Assoc-voc       37.789474
#           Bachelors       35.667566
#           Doctorate       44.850000
#           HS-grad         38.626087
#           Masters         43.135729
#           Preschool       40.133333
#           Prof-school     40.058824
#           Some-college    33.751845
#  Male     10th            38.159091
#           11th            33.563319
#           12th            33.112782
#           1st-4th         45.692308
#           5th-6th         42.598291
#           7th-8th         47.893805
#           9th             40.913793
#           Assoc-acdm      37.944162
#           Assoc-voc       39.023399
#           Bachelors       40.331685
#           Doctorate       48.396104
#           HS-grad         39.089150
#           Masters         44.750457
#           Preschool       42.906250
#           Prof-school     45.607623
#           Some-college    37.045663
# Name: age, dtype: float64

# %% [markdown]
# ##### Q3. What is the average contribution to capital-gain of each sex and occupation category?
#
#
#                             ANSWER

# %% [markdown]
# The average contribution to capital-gain of each sex

# %%
data['capital-gain'].groupby([data['sex']]).mean()
# Out:
# sex
#  Female     546.062405
#  Male      1334.969100
# Name: capital-gain, dtype: float64

# %% [markdown]
# The average contribution to capital-gain of each occupation category.

# %%
data['capital-gain'].groupby([data['occupation']]).mean()
# Out:
# occupation
#  ?                     614.206198
#  Adm-clerical          524.931214
#  Armed-Forces            0.000000
#  Craft-repair          666.146903
#  Exec-managerial      2263.708746
#  Farming-fishing       567.100223
#  Handlers-cleaners     185.401569
#  Machine-op-inspct     338.375599
#  Other-service         161.597965
#  Priv-house-serv       289.225564
#  Prof-specialty       2670.550459
#  Protective-serv       666.846154
#  Sales                1365.213523
#  Tech-support          678.293503
#  Transport-moving      494.641781
# Name: capital-gain, dtype: float64

# %% [markdown]
# ###### Q4. Identify the average capital-gain by males and females accross different marital-status.
#
#                ANSWER
#              The average average capital-gain by males and females accross different marital-status is shown below

# %%
data['capital-gain'].groupby([data['sex'],data['marital-status']]).mean()
# Out:
# sex      marital-status
#  Female   Divorced                  452.086601
#           Married-AF-spouse         189.500000
#           Married-civ-spouse       1527.466623
#           Married-spouse-absent     383.697297
#           Never-married             319.586332
#           Separated                 194.157986
#           Widowed                   524.287433
#  Male     Divorced                 1110.794226
#           Married-AF-spouse         810.888889
#           Married-civ-spouse       1806.516153
#           Married-spouse-absent     986.150000
#           Never-married             411.749863
#           Separated                 592.784916
#           Widowed                  1019.164474
# Name: capital-gain, dtype: float64

# %% [markdown]
# Question. What is the maximum age accross differnt races?
#
#                 ANSWER
#             Let's first see what are the different races and then apply groupby.

# %%
data['race'].value_counts()
# Out:
#  White                 25608
#  Black                  2898
#  Asian-Pac-Islander      970
#  Amer-Indian-Eskimo      283
#  Other                   241
# Name: race, dtype: int64

# %%
data['age'].groupby([data['race']]).max()
# Out:
# race
#  Amer-Indian-Eskimo    82
#  Asian-Pac-Islander    90
#  Black                 90
#  Other                 77
#  White                 90
# Name: age, dtype: int64

# %% [markdown]
# ANSWER: The maximum age by race is     Amer-Indian-Eskimo 82, Asian-Pac-Islander   90,  Black  90,  Other 77,  White 90

# %% [markdown]
#   Q5. Are minimum and maximum age by sex same?

# %%
#Minimum age by sex:

data['age'].groupby([data['sex']]).min()
# Out:
# sex
#  Female    17
#  Male      17
# Name: age, dtype: int64

# %%
#maximum age by sex:
data['age'].groupby([data['sex']]).max()
# Out:
# sex
#  Female    90
#  Male      90
# Name: age, dtype: int64

# %% [markdown]
# ANSWER:
#  The  minimum and maximum age by sex same are the same

# %% [markdown]
# # DATA VISUALISATION

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  30000.000000   30000.000000  30000.000000  30000.000000    30000.000000
# mean      38.588733      10.077967   1074.551000     87.514767       40.433033
# std       13.619539       2.579698   7394.107726    403.735249       12.315220
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %%
data['age'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='age')
# Out:
# <AxesSubplot:>

# %%
data['capital-gain'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='capital-gain')
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column='age', by = 'education', grid=False, rot = 45, fontsize = 10)
# Out:
# <AxesSubplot:title={'center':'age'}, xlabel='education'>

# %%
data['education'].value_counts()
# Out:
#  HS-grad         9667
#  Some-college    6714
#  Bachelors       4920
#  Masters         1595
#  Assoc-voc       1268
#  11th            1091
#  Assoc-acdm       980
#  10th             842
#  7th-8th          598
#  Prof-school      531
#  9th              481
#  12th             404
#  Doctorate        388
#  5th-6th          312
#  1st-4th          162
#  Preschool         47
# Name: education, dtype: int64

# %%
data.boxplot(column='capital-gain', by = 'education', grid=False, rot = 45, fontsize = 10)
# Out:
# <AxesSubplot:title={'center':'capital-gain'}, xlabel='education'>

# %%
data['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       13802
#  Never-married             9880
#  Divorced                  4076
#  Separated                  934
#  Widowed                    900
#  Married-spouse-absent      385
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %% [markdown]
# # Checking NULL values in the dataset

# %%
data.apply(lambda x: sum(x.isnull()), axis = 0)
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# class-label       0
# dtype: int64

# %% [markdown]
# # Data transformation

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.head()
# Out:
#        age   workclass education  education-num       marital-status  \
# 23176   18           ?   HS-grad              9        Never-married
# 22684   54     Private   Masters             14   Married-civ-spouse
# 14705   54     Private      10th              6            Separated
# 8186    21     Private   HS-grad              9            Separated
# 28725   52   State-gov   HS-grad              9            Separated
#
#                occupation     relationship    race      sex  capital-gain  \
# 23176                   ?        Own-child   White   Female             0
# 22684      Prof-specialty          Husband   White     Male             0
# 14705               Sales        Unmarried   White   Female             0
# 8186    Machine-op-inspct   Other-relative   White     Male             0
# 28725       Other-service    Not-in-family   White   Female             0
#
#        capital-loss  hours-per-week  native-country class-label
# 23176             0              20   United-States       <=50K
# 22684             0              40   United-States        >50K
# 14705             0              43           Italy       <=50K
# 8186              0              40   United-States       <=50K
# 28725             0              35   United-States       <=50K

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# class-label       object
# dtype: object

# %%
columns = list(data.select_dtypes(exclude=['int64']))

# %%
columns
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'class-label']

# %%
data['class-label'].value_counts()
# Out:
#  <=50K    22763
#  >50K      7237
# Name: class-label, dtype: int64

# %%
le = LabelEncoder()
for i in columns:
 #print(i)
 data[i] = le.fit_transform(data[i])
data.dtypes
# Out:
# age               int64
# workclass         int32
# education         int32
# education-num     int64
# marital-status    int32
# occupation        int32
# relationship      int32
# race              int32
# sex               int32
# capital-gain      int64
# capital-loss      int64
# hours-per-week    int64
# native-country    int32
# class-label       int32
# dtype: object

# %%
data.head(10)
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 23176   18          0         11              9               4           0
# 22684   54          4         12             14               2          10
# 14705   54          4          0              6               5          12
# 8186    21          4         11              9               5           7
# 28725   52          7         11              9               5           8
# 14214   32          4         11              9               2          12
# 3820    24          6          9             13               4           5
# 2448    29          2         11              9               4          11
# 23832   27          4          8             11               4           8
# 24058   18          4          0              6               4          12
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 23176             3     4    0             0             0              20
# 22684             0     4    1             0             0              40
# 14705             4     4    0             0             0              43
# 8186              2     4    1             0             0              40
# 28725             1     4    0             0             0              35
# 14214             0     1    1             0             0              40
# 3820              4     4    1             0             0              50
# 2448              1     2    0             0             0              40
# 23832             1     1    0             0             0              40
# 24058             1     4    1             0             0              20
#
#        native-country  class-label
# 23176              39            0
# 22684              39            1
# 14705              22            0
# 8186               39            0
# 28725              39            0
# 14214              17            0
# 3820               39            0
# 2448               39            0
# 23832              30            0
# 24058              39            0

# %%
data['workclass'].value_counts()
# Out:
# 4    20935
# 6     2331
# 2     1923
# 0     1671
# 7     1198
# 5     1029
# 1      892
# 8       14
# 3        7
# Name: workclass, dtype: int64

# %%
data['education'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data.describe(include='all')
# Out:
#                 age     workclass     education  education-num  \
# count  30000.000000  30000.000000  30000.000000   30000.000000
# mean      38.588733      3.870933     10.296833      10.077967
# std       13.619539      1.452863      3.869723       2.579698
# min       17.000000      0.000000      0.000000       1.000000
# 25%       28.000000      4.000000      9.000000       9.000000
# 50%       37.000000      4.000000     11.000000      10.000000
# 75%       48.000000      4.000000     12.000000      12.000000
# max       90.000000      8.000000     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count     30000.00000  30000.000000  30000.000000  30000.000000  30000.000000
# mean          2.61240      6.581867      1.442900      3.664033      0.669900
# std           1.50321      4.223248      1.604148      0.850598      0.470257
# min           0.00000      0.000000      0.000000      0.000000      0.000000
# 25%           2.00000      3.000000      0.000000      4.000000      0.000000
# 50%           2.00000      7.000000      1.000000      4.000000      1.000000
# 75%           4.00000     10.000000      3.000000      4.000000      1.000000
# max           6.00000     14.000000      5.000000      4.000000      1.000000
#
#        capital-gain  capital-loss  hours-per-week  native-country  \
# count  30000.000000  30000.000000    30000.000000    30000.000000
# mean    1074.551000     87.514767       40.433033       36.709700
# std     7394.107726    403.735249       12.315220        7.835786
# min        0.000000      0.000000        1.000000        0.000000
# 25%        0.000000      0.000000       40.000000       39.000000
# 50%        0.000000      0.000000       40.000000       39.000000
# 75%        0.000000      0.000000       45.000000       39.000000
# max    99999.000000   4356.000000       99.000000       41.000000
#
#         class-label
# count  30000.000000
# mean       0.241233
# std        0.427839
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ##### Q9. Which occupation represents more males than females?
#
#                 ANSWER

# %%
data['occupation'].groupby([data['sex']]).value_counts()
# Out:
# sex  occupation
# 0    1             2335
#      8             1654
#      10            1399
#      12            1162
#      4             1065
#      0              760
#      7              513
#      13             324
#      3              202
#      6              153
#      9              125
#      14              82
#      11              69
#      5               60
# 1    3             3576
#      4             2674
#      10            2416
#      12            2210
#      8             1393
#      14            1378
#      7             1364
#      1             1125
#      6             1122
#      0              918
#      5              838
#      13             538
#      11             529
#      2                8
#      9                8
# Name: occupation, dtype: int64

# %% [markdown]
# ##### The difference betwen data head and data tail

# %%
data.head(10)
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 23176   18          0         11              9               4           0
# 22684   54          4         12             14               2          10
# 14705   54          4          0              6               5          12
# 8186    21          4         11              9               5           7
# 28725   52          7         11              9               5           8
# 14214   32          4         11              9               2          12
# 3820    24          6          9             13               4           5
# 2448    29          2         11              9               4          11
# 23832   27          4          8             11               4           8
# 24058   18          4          0              6               4          12
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 23176             3     4    0             0             0              20
# 22684             0     4    1             0             0              40
# 14705             4     4    0             0             0              43
# 8186              2     4    1             0             0              40
# 28725             1     4    0             0             0              35
# 14214             0     1    1             0             0              40
# 3820              4     4    1             0             0              50
# 2448              1     2    0             0             0              40
# 23832             1     1    0             0             0              40
# 24058             1     4    1             0             0              20
#
#        native-country  class-label
# 23176              39            0
# 22684              39            1
# 14705              22            0
# 8186               39            0
# 28725              39            0
# 14214              17            0
# 3820               39            0
# 2448               39            0
# 23832              30            0
# 24058              39            0

# %%
data.tail(10)
# Out:
#        age  workclass  education  education-num  marital-status  occupation  \
# 14170   49          4         15             10               0           8
# 21060   41          2         15             10               0           4
# 29530   47          4         11              9               2           6
# 16199   30          4         11              9               4           5
# 20193   49          4         10             16               2          10
# 29256   50          6         11              9               2          12
# 20266   25          0          9             13               4           0
# 22236   38          6          7             12               2          12
# 23713   30          2          9             13               2          11
# 6663    18          0         15             10               4           0
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 14170             1     4    0             0             0              40
# 21060             1     4    0             0             0              40
# 29530             5     2    0             0             0              40
# 16199             3     4    1             0             0              40
# 20193             0     3    1             0             0              50
# 29256             0     2    1             0             0              40
# 20266             3     4    0             0             0              30
# 22236             0     4    1             0             0              60
# 23713             0     4    1             0             0              40
# 6663              3     4    1             0             0              40
#
#        native-country  class-label
# 14170              39            0
# 21060              39            0
# 29530              39            0
# 16199              39            0
# 20193              39            1
# 29256              39            0
# 20266              39            0
# 22236              39            0
# 23713              39            0
# 6663               39            0
